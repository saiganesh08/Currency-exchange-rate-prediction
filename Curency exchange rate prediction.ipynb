# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import regression

# %%
sns.set()
plt.style.use('seaborn-whitegrid')

data = pd.read_csv("INR=X (1).csv")
print(data.head())
print(data.tail())
# Out:
#          Date       Open       High        Low      Close  Adj Close  Volume
# 0  2022-02-25  75.408302  75.659500  75.064499  75.408302  75.408302       0
# 1  2022-02-28  75.055199  75.786003  74.900002  75.068001  75.068001       0
# 2  2022-03-01  75.284798  75.895103  75.212196  75.284798  75.284798       0
# 3  2022-03-02  75.801102  76.096497  75.428299  75.801201  75.801201       0
# 4  2022-03-03  75.638298  76.018997  75.571999  75.630997  75.630997       0
#            Date       Open       High        Low      Close  Adj Close  Volume
# 257  2023-02-21  82.697502  82.889900  82.672997  82.697502  82.697502       0
# 258  2023-02-22  82.861198  82.995300  82.779503  82.861198  82.861198       0
# 259  2023-02-23  82.835297  82.903000  82.563004  82.835297  82.835297       0
# 260  2023-02-24  82.617897  83.005203  82.609497  82.617897  82.617897       0
# 261  2023-02-25  82.876999  82.876999  82.876999  82.876999  82.876999       0

# %%
plt.figure(figsize=(15, 12))
plt.title("INR - USD Exchange Rate")
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(data["Close"])
plt.show()

# %%
print(data.corr())
sns.heatmap(data.corr())
plt.show()
# Out:
#                Open      High       Low     Close  Adj Close  Volume
# Open       1.000000  0.997244  0.997510  1.000000   1.000000     NaN
# High       0.997244  1.000000  0.996215  0.997249   0.997249     NaN
# Low        0.997510  0.996215  1.000000  0.997510   0.997510     NaN
# Close      1.000000  0.997249  0.997510  1.000000   1.000000     NaN
# Adj Close  1.000000  0.997249  0.997510  1.000000   1.000000     NaN
# Volume          NaN       NaN       NaN       NaN        NaN     NaN

# %%
x = data[["Open", "High", "Low"]]
y = data["Close"]
x = x.to_numpy()
y = y.to_numpy()
y = y.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)

# %%
data = pd.DataFrame(data={"Predicted Rate": ypred.flatten()})
print(data.head())
print(data.tail())
# Out:
#    Predicted Rate
# 0       82.737701
# 1       82.876999
# 2       81.637398
# 3       82.279198
# 4       77.630203
#     Predicted Rate
# 48       78.193100
# 49       79.627602
# 50       82.239197
# 51       82.835297
# 52       78.441101
